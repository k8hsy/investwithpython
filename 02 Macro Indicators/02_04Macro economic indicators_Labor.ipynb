# %%
# 1. Import Libraries
import pandas as pd                 # Pandas Library
import matplotlib.pyplot as plt     # Matplot Library
import seaborn as sns               # Seaborn Library
import FinanceDataReader as fdr

# %% [markdown]
# Unemployment Rate (UNRATE)
# Observation:Feb 2023: 3.6
#
# Updated: Mar 10, 2023
# Units:Percent,Seasonally Adjusted
# Frequency:Monthly

# %%
df_unemp = fdr.DataReader('FRED:UNRATE',start='1947')     # start from year 1947
df_unemp=df_unemp.rename(columns={'UNRATE':'Unemployment Rate'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_unemp.plot()
df_unemp
# Out:
#             Unemployment Rate
# DATE
# 1948-01-01                3.4
# 1948-02-01                3.8
# 1948-03-01                4.0
# 1948-04-01                3.9
# 1948-05-01                3.5
# ...                       ...
# 2022-10-01                3.7
# 2022-11-01                3.6
# 2022-12-01                3.5
# 2023-01-01                3.4
# 2023-02-01                3.6
#
# [902 rows x 1 columns]

# %% [markdown]
# Average Hourly Earnings of All Employees, Total Private (CES0500000003)
# Observation:Feb 2023: 33.09
#
# Updated: Mar 10, 2023
# Units:Dollars per Hour,Seasonally Adjusted
# Frequency:Monthly
# The Average Hourly Earnings of All Private Employees is a measure of the average hourly earnings of all private employees on a “gross” basis, including premium pay for overtime and late-shift work. These differ from wage rates in that average hourly earnings measure the actual return to a worker for a set period of time, rather than the amount contracted for a unit of work, the wage rate. This measure excludes benefits, irregular bonuses, retroactive pay, and payroll taxes paid by the employer.
#
# Average Hourly Earnings are collected in the Current Employment Statistics (CES) program and published by the BLS. It is provided on a monthly basis, so this data is used in part by macroeconomists as an initial economic indicator of current trends. Progressions in earnings specifically help policy makers understand some of the pressures driving inflation.
#
# It is important to note that this series measures the average hourly earnings of the pool of workers in each period. Thus, changes in average hourly earnings can be due to either changes in the set of workers observed in a given period, or due to changes in earnings. For instance, in recessions that lead to the disproportionate increase of unemployment in lower-wage jobs, average hourly earnings can increase due to changes in the pool of workers rather than due to the widespread increase of hourly earnings at the worker-level.

# %%
df_ahe = fdr.DataReader('FRED:CES0500000003',start='1947')     # start from year 1947
df_ahe=df_ahe.rename(columns={'CES0500000003':'Average Hourly Earnings'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_ahe.plot()
df_ahe
# Out:
#             Average Hourly Earnings
# DATE
# 2006-03-01                    20.04
# 2006-04-01                    20.15
# 2006-05-01                    20.13
# 2006-06-01                    20.23
# 2006-07-01                    20.29
# ...                             ...
# 2022-10-01                    32.66
# 2022-11-01                    32.80
# 2022-12-01                    32.92
# 2023-01-01                    33.01
# 2023-02-01                    33.09
#
# [204 rows x 1 columns]

# %% [markdown]
# All Employees, Total Private (USPRIV)
# Observation:Feb 2023: 132,855
#
# Updated: Mar 10, 2023
# Units:Thousands of Persons,Seasonally Adjusted
# Frequency:Monthly

# %%
df_allemp = fdr.DataReader('FRED:USPRIV',start='1947')     # start from year 1947
df_allemp=df_allemp.rename(columns={'USPRIV':'All Employees total Private'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_allemp.plot()
df_allemp
# Out:
#             All Employees total Private
# DATE
# 1947-01-01                        37916
# 1947-02-01                        37951
# 1947-03-01                        38019
# 1947-04-01                        37941
# 1947-05-01                        38087
# ...                                 ...
# 2022-10-01                       131744
# 2022-11-01                       131972
# 2022-12-01                       132204
# 2023-01-01                       132590
# 2023-02-01                       132855
#
# [914 rows x 1 columns]

# %% [markdown]
# All Employees, Total Nonfarm (PAYEMS)
# Observation:Feb 2023: 155,350
#
# Updated: Mar 10, 2023
# Units:Thousands of Persons,Seasonally Adjusted
# Frequency:Monthly
#
# All Employees: Total Nonfarm, commonly known as Total Nonfarm Payroll, is a measure of the number of U.S. workers in the economy that excludes proprietors, private household employees, unpaid volunteers, farm employees, and the unincorporated self-employed. This measure accounts for approximately 80 percent of the workers who contribute to Gross Domestic Product (GDP).
#
# This measure provides useful insights into the current economic situation because it can represent the number of jobs added or lost in an economy. Increases in employment might indicate that businesses are hiring which might also suggest that businesses are growing. Additionally, those who are newly employed have increased their personal incomes, which means (all else constant) their disposable incomes have also increased, thus fostering further economic expansion.
#
# Generally, the U.S. labor force and levels of employment and unemployment are subject to fluctuations due to seasonal changes in weather, major holidays, and the opening and closing of schools. The Bureau of Labor Statistics (BLS) adjusts the data to offset the seasonal effects to show non-seasonal changes: for example, women's participation in the labor force; or a general decline in the number of employees, a possible indication of a downturn in the economy. To closely examine seasonal and non-seasonal changes, the BLS releases two monthly statistical measures: the seasonally adjusted All Employees: Total Nonfarm (PAYEMS) and All Employees: Total Nonfarm (PAYNSA), which is not seasonally adjusted.
#
# The series comes from the 'Current Employment Statistics (Establishment Survey).'

# %%
df_allempnp = fdr.DataReader('FRED:PAYEMS',start='1939')     # start from year 1939
df_allempnp=df_allempnp.rename(columns={'PAYEMS':'All Employees Nonfarm'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_allempnp.plot()
df_allempnp
# Out:
#             All Employees Nonfarm
# DATE
# 1939-01-01                  29923
# 1939-02-01                  30100
# 1939-03-01                  30280
# 1939-04-01                  30094
# 1939-05-01                  30299
# ...                           ...
# 2022-10-01                 154006
# 2022-11-01                 154296
# 2022-12-01                 154535
# 2023-01-01                 155039
# 2023-02-01                 155350
#
# [1010 rows x 1 columns]

# %% [markdown]
# Initial Claims (ICSA)
# Observation:2023-03-25: 198,000
#
# Updated: 7:38 AM CDT
# Units:Number,Seasonally Adjusted
# Frequency:Weekly,Ending Saturday
#
# An initial claim is a claim filed by an unemployed individual after a separation from an employer. The claim requests a determination of basic eligibility for the Unemployment Insurance program.

# %%
df_Icsa = fdr.DataReader('FRED:ICSA',start='1967')     # start from year 1967
df_Icsa=df_Icsa.rename(columns={'ICSA':'Initial Claims'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_Icsa.plot()
df_Icsa
# Out:
#             Initial Claims
# DATE
# 1967-01-07          208000
# 1967-01-14          207000
# 1967-01-21          217000
# 1967-01-28          204000
# 1967-02-04          216000
# ...                    ...
# 2023-02-25          190000
# 2023-03-04          212000
# 2023-03-11          192000
# 2023-03-18          191000
# 2023-03-25          198000
#
# [2934 rows x 1 columns]
