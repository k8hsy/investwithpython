# %%
# 1. Import Libraries
import pandas as pd                 # Pandas Library
import numpy as np                  # Numpy Library
import matplotlib.pyplot as plt     # Matplot Library
import seaborn as sns               # Seaborn Library
import FinanceDataReader as fdr

# %% [markdown]
# 1. Real Gross Domestic Product percent change (A191RL1Q225SBEA)
# Observation:Q4 2022: 2.7
#
# Updated: Feb 23, 2023
# Units:Percent Change from Preceding Period,Seasonally Adjusted Annual Rate
# Frequency:Quarterly
# Source: U.S. Bureau of Economic Analysis  Release: Gross Domestic Product
#
# Gross domestic product (GDP) is the value of the goods and services produced by the nation's economy less the value of the goods and services used up in production. GDP is also equal to the sum of personal consumption expenditures, gross private domestic investment, net exports of goods and services, and government consumption expenditures and gross investment. Real values are inflation-adjusted estimates—that is, estimates that exclude the effects of price changes.

# %%
df_gdp_q = fdr.DataReader('FRED:A191RL1Q225SBEA',start='1947')     # start from year 1947
df_gdp_q=df_gdp_q.rename(columns={'A191RL1Q225SBEA':'GDP Growth'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_gdp_q.plot()
df_gdp_q
# Out:
#             GDP Growth
# DATE
# 1947-04-01        -1.1
# 1947-07-01        -0.8
# 1947-10-01         6.4
# 1948-01-01         6.2
# 1948-04-01         6.8
# ...                ...
# 2021-10-01         7.0
# 2022-01-01        -1.6
# 2022-04-01        -0.6
# 2022-07-01         3.2
# 2022-10-01         2.6
#
# [303 rows x 1 columns]

# %% [markdown]
# 2. Gross Domestic Product (GDP)
# Q4 2022: 26,144.956 (+ more)
# Updated: Feb 23, 2023
# Units:Billions of Dollars,
# Seasonally Adjusted Annual Rate
# Frequency:Quarterly
# Gross Domestic Product (GDP)
# Observation:
#
# Gross domestic product (GDP), the featured measure of U.S. output, is the market value of the goods and services produced by labor and property located in the United States.For more information, see the Guide to the National Income and Product Accounts of the United States (NIPA) and the Bureau of Economic Analysis.

# %%
df_gdp = fdr.DataReader('FRED:GDP',start='1947')     # start from year 1947
plt.rcParams["figure.figsize"] = (20,8) # size set
df_gdp.plot()
df_gdp
# Out:
#                   GDP
# DATE
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
# 2022-10-01  26137.992
#
# [304 rows x 1 columns]

# %% [markdown]
# 3. Real gross domestic product per capita (A939RX0Q048SBEA)
# Observation:Q4 2022: 60,391
#
# Updated: Feb 23, 2023
# Units:Chained 2012 Dollars,Seasonally Adjusted Annual Rate
# Frequency:Quarterly

# %%
df_gdp_pc = fdr.DataReader('FRED:A939RX0Q048SBEA',start='1947')     # start from year 1947
df_gdp_pc=df_gdp_pc.rename(columns={'A939RX0Q048SBEA':'GDP per Capita'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_gdp_pc.plot()
df_gdp_pc
# Out:
#             GDP per Capita
# DATE
# 1947-01-01         14213.0
# 1947-04-01         14111.0
# 1947-07-01         14018.0
# 1947-10-01         14171.0
# 1948-01-01         14326.0
# ...                    ...
# 2021-10-01         60117.0
# 2022-01-01         59836.0
# 2022-04-01         59688.0
# 2022-07-01         60080.0
# 2022-10-01         60376.0
#
# [304 rows x 1 columns]

# %% [markdown]
# 4. Gross Federal Debt as Percent of Gross Domestic Product (GFDGDPA188S)
# Observation:2022: 121.10446
#
# Updated: Mar 20, 2023
# Units:Percent of GDP,Not Seasonally Adjusted
# Frequency:Annual
#
# Gross Federal Debt as Percent of Gross Domestic Product (GFDGDPA188S) was first constructed by the Federal Reserve Bank of St. Louis in January 2013. It is calculated using Gross Federal Debt (FYGFD) and Gross Domestic Product (GDPA):
# GFDGDPA188S = (FYGFD/GDPA)*100

# %%
df_fdebt_gdp = fdr.DataReader('FRED:GFDGDPA188S',start='1947')     # start from year 1947
df_fdebt_gdp=df_fdebt_gdp.rename(columns={'GFDGDPA188S':'Fed Debt to GDP'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_fdebt_gdp.plot()
df_fdebt_gdp
# Out:
#             Fed Debt to GDP
# DATE
# 1947-01-01        102.99821
# 1948-01-01         91.81398
# 1949-01-01         92.70575
# 1950-01-01         85.68274
# 1951-01-01         73.59173
# ...                     ...
# 2018-01-01        104.52559
# 2019-01-01        106.02650
# 2020-01-01        127.73929
# 2021-01-01        121.74781
# 2022-01-01        121.11274
#
# [76 rows x 1 columns]

# %% [markdown]
# 5. Household Debt to GDP for United States (HDTGPDUSQ163N)
# Observation:Q3 2022: 76.82961
#
# Updated: Feb 1, 2023
# Units: Ratio, Not Seasonally Adjusted
# Frequency:Quarterly
#
# The data for household debt comprise debt incurred by resident households of the economy only. This FSI measures the overall level of household indebtedness (commonly related to consumer loans and mortgages) as a share of GDP.

# %%
df_hdebt_gdp = fdr.DataReader('FRED:HDTGPDUSQ163N',start='2005')     # start from year 2005
df_hdebt_gdp=df_hdebt_gdp.rename(columns={'HDTGPDUSQ163N':'Household Debt to GDP'}) # column name change

plt.rcParams["figure.figsize"] = (20,8) # size set
df_hdebt_gdp.plot()
df_hdebt_gdp
# Out:
#             Household Debt to GDP
# DATE
# 2005-01-01              87.157525
# 2005-04-01              89.708126
# 2005-07-01              92.393651
# 2005-10-01              94.648123
# 2006-01-01              91.952054
# ...                           ...
# 2021-07-01              78.138204
# 2021-10-01              79.834824
# 2022-01-01              74.110958
# 2022-04-01              75.550657
# 2022-07-01              76.829614
#
# [71 rows x 1 columns]
